# %%
import math

from pygments.styles.dracula import selection


class DuongTron:
    def __init__(self, ban_Kinh):
        self._ban_Kinh = ban_Kinh
    def xuat(self):
        print(f'Đường tròn có r = {self._ban_Kinh}')
    def chuVi(self):
        return 2*self._ban_Kinh*math.pi
    def dienTich(self):
        return 2*(self._ban_Kinh**2 )*math.pi

# %%
# Out:
# Tam giác có các cạnh: 1-2-3
