# %%
s1var1 = 10
print("Giá trị var1", var1,"\n\t Kiểu của var1 ", type(var1))
# Out:
# Giá trị var1 10
# 	 Kiểu của var1  <class 'int'>

# %%
var2 = float(var1)
print("Giá trị var2 = ", var2, "\n\t Kiểu của var2", type(var2))
# Out:
# Giá trị var2 =  10.0
# 	 Kiểu của var <class 'float'>

# %%
var3 = 3 + 4j
print("Giá trị của var3= ", var3, "\n\t Kiểu của var3",type(var3))
# Out:
# Giá trị của var3=  (3+4j)
# 	 Kiểu của var3 <class 'complex'>

# %%
var4 = complex(var2)
print("Giá trị của var4= ",var4, "\n\t Kiểu của var4",type(var4))
# Out:
# Giá trị của var4=  (10+0j)
# 	 Kiểu của var4 <class 'complex'>

# %%
a =5
b = 10
print(a//b)
# Out:
# 0

# %%
int(5)
# Out:
# 5

# %%
complex(5)
# Out:
# (5+0j)

# %%
abs(-5)
# Out:
# 5

# %%
pow(5,5)
# Out:
# 3125

# %%
round(5.666666,3)
# Out:
# 5.667

# %%
import math as m

# %%
m.sqrt(5)
# Out:
# 2.23606797749979

# %%
m.fabs(-6)
# Out:
# 6.0

# %%
m.ceil(5.4)
# Out:
# 6

# %%
a =1,
print (a)
# Out:
# (1,)

# %%
t1=(1)
t2=(1,)
print (t1)
print(t2)
print(type(t1))
print(type(t2))
# Out:
# 1
# (1,)
# <class 'int'>
# <class 'tuple'>

# %%
t3  = (1,2,3,4,5)
print(t3)
# Out:
# (1, 2, 3, 4, 5)

# %%
t3[3]=5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 t3[3]=5
#
# TypeError: 'tuple' object does not support item assignment

# %%
tup3 = 'a', 'b', 'c', 'd', 'e'
print(type(tup3))
# Out:
# <class 'tuple'>

# %%
print(tup3[-1])
# Out:
# e

# %%
tup1=(1,2,3)
tup2=(4,5,6)
tup3=tup1+tup2
print(tup3)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
tup1 = tup1 +(15,)

# %%
print(tup1)

# %%
t10 = (1,4,2,4,5,6)
num = t10.count(4)

# %%
print(num)

# %%
ds = sorted(t10)
print(ds)

# %%
print(t10)

# %%
t10.sort()

# %%
s1 = set ([1,4,2,3,5])
print(s1)
# Out:
# {1, 2, 3, 4, 5}

# %%
s2 = set()
print(type(s2))
# Out:
# <class 'set'>

# %%
s1 = {1,2,3,4,5}
s2 = {1,3,5,7,9}
print('s1 hợp s2', s1 | s2)
print('s1 giao s2', s1 & s2)
print('s1 hiệu s2', s1 - s2)
print('s1 hiệu s2', s1 ^ s2)
# Out:
# s1 hợp s2 {1, 2, 3, 4, 5, 7, 9}
# s1 giao s2 {1, 3, 5}
# s1 hiệu s2 {2, 4}
# s1 hiệu s2 {2, 4, 7, 9}

# %%
s1.add(6)
print(s1)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
import random
set1 = set(random.sample(range(0,100),10))
set2 = set(random.sample(range(0,100),10))
print(set1)
print(set2)
print(set1.issubset(set2))
print(set1.issuperset(set2))
# Out:
# {0, 34, 9, 12, 45, 55, 88, 25, 59, 93}
# {32, 35, 70, 39, 47, 24, 25, 27, 93, 95}
# False
# False

# %%
import random
def taongaunhien():
    s = set()
    for i in range(10):
        s1.add(random.randint(11,100))
    return s

# %%
s1 = set(taongaunhien())
print(s1)
# Out:
# set()

# %%
s2 = taongaunhien()
print(s2)
# Out:
# set()

# %%
d = {'name': ' tran',
     'age': 37,
     'coutry': 'Viet Nam'
     }

# %%
d.items()
# Out:
# dict_items([('name', ' tran'), ('age', 37), ('coutry', 'Viet Nam')])

# %%
d.keys()
# Out:
# dict_keys(['name', 'age', 'coutry'])

# %%
d.values()
# Out:
# dict_values([' tran', 37, 'Viet Nam'])

# %%
d['name']
# Out:
# ' tran'

# %%
d['city'] = ' Ho Chi Minh'

# %%
d
# Out:
# {'name': ' tran', 'age': 37, 'coutry': 'Viet Nam', 'city': ' Ho Chi Minh'}

# %%
d['city'] = 'Da Nang'

# %%
d
# Out:
# {'name': ' tran', 'age': 37, 'coutry': 'Viet Nam', 'city': 'Da Nang'}

# %%
del d['city']

# %%
d
# Out:
# {'name': ' tran', 'age': 37, 'coutry': 'Viet Nam'}

# %%
len(d)
# Out:
# 3

# %%
str(d)
# Out:
# "{'name': ' tran', 'age': 37, 'coutry': 'Viet Nam'}"

# %%
d.get('name')
# Out:
# ' tran'

# %%
d.fromkeys('country')
# Out:
# {'c': None, 'o': None, 'u': None, 'n': None, 't': None, 'r': None, 'y': None}

# %%
d.fromkeys(['name','age','address'])
# Out:
# {'name': None, 'age': None, 'address': None}

# %%
d.pop('name')
# Out:
# ' tran'

# %%
d
# Out:
# {'age': 37, 'coutry': 'Viet Nam'}
