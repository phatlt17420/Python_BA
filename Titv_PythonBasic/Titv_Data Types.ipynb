# %%
from traceback import print_tb

listNew = ['cam','bưởi','quýt','cam','bưởi','quýt','cam','bưởi','quýt', 'Thành']
# đếm phần tử trong list
listNew.count('bưởi')
# Out:
# 0

# %%
danhSach = 'Lê Tấn Phát \n'
danhSach1 = 'Lê'
if danhSach1 in danhSach:
    print('tô tại')
# Out:
# tô tại

# %%
sinhVien = {
    'hoVaTen':'Lê Tấn Phát',
    'maLop':'DH01',
    'diemTrungBinh': 8.5
}
print(sinhVien)
# Out:
# {'hoVaTen': 'Lê Tấn Phát', 'maLop': 'DH01', 'diemTrungBinh': 8.5}

# %%
print(sinhVien.get('diemTrungBinh'))
# Out:
# 8.5

# %%
sinhVien['diemTrungBinh'] = 10
print(sinhVien)
# Out:
# {'hoVaTen': 'Lê Tấn Phát', 'maLop': 'DH01', 'diemTrungBinh': 10}

# %%
sinhVien.update({'diemTrungBinh':5, 'maLop':'DH10'})

# %%
print(sinhVien)
# Out:
# {'hoVaTen': 'Lê Tấn Phát', 'maLop': 'DH10', 'diemTrungBinh': 5}

# %%
sinhVien['noi sinh']='TIền Giang'

# %%
print(sinhVien)
# Out:
# {'hoVaTen': 'Lê Tấn Phát', 'maLop': 'DH10', 'diemTrungBinh': 5, 'noi sinh': 'TIền Giang'}

# %%
sinhVien.update({'noi sinh':"Đồng Tháp",'NOi ở':'TP.HCM'})
print(sinhVien)
# Out:
# {'hoVaTen': 'Lê Tấn Phát', 'maLop': 'DH10', 'diemTrungBinh': 5, 'noi sinh': 'Đồng Tháp', 'NOi ở': 'TP.HCM'}
