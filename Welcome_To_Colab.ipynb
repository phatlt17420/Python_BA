# %% [markdown]
# <a href="https://colab.research.google.com/github/phatlt17420/Python_BA/blob/master/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
